# %%
# !pip install pandas
# !pip install pypdf
# !pip install pypdf2
# !pip install cryptography
# !pip install pikepdf
# !pip install streamlit
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pypdf in ./.venv/lib/python3.13/site-packages (5.1.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pypdf2 in ./.venv/lib/python3.13/site-packages (3.0.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: cryptography in ./.venv/lib/python3.13/site-packages (44.0.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.13/site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.13/site-packages (from cffi>=1.12->cryptography) (2.22)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pikepdf in ./.venv/lib/python3.13/site-packages (9.4.2)
# Requirement already satisfied: Pillow>=10.0.1 in ./.venv/lib/python3.13/site-packages (from pikepdf) (11.0.0)
# Requirement already satisfied: Deprecated in ./.venv/lib/python3.13/site-packages (from pikepdf) (1.2.15)
# Requirement already satisfied: lxml>=4.8 in ./.venv/lib/python3.13/site-packages (from pikepdf) (5.3.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from pikepdf) (24.2)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.13/site-packages (from Deprecated->pikepdf) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: streamlit in ./.venv/lib/python3.13/site-packages (1.41.1)
# Requirement already satisfied: altair<6,>=4.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in ./.venv/lib/python3.13/site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: packaging<25,>=20 in ./.venv/lib/python3.13/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in ./.venv/lib/python3.13/site-packages (from streamlit) (5.29.1)
# Requirement already satisfied: pyarrow>=7.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in ./.venv/lib/python3.13/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.venv/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./.venv/lib/python3.13/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./.venv/lib/python3.13/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.venv/lib/python3.13/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.venv/lib/python3.13/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in ./.venv/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import shutil
import pikepdf
import re
import pandas as pd
from PyPDF2 import PdfReader


# Caminhos das pastas
source_folder = "./maps/encrypted/"
processed_folder = os.path.join(source_folder, "processed")
decrypted_folder = "./maps/decrypted/"
decrypted_processed_folder = os.path.join(decrypted_folder, "processed")

# Função para verificar e criar a hierarquia de pastas
def ensure_folders_exist():
    folders = [source_folder, processed_folder, decrypted_folder, decrypted_processed_folder]
    for folder in folders:
        if not os.path.exists(folder):
            os.makedirs(folder)
            print(f"Pasta criada: {folder}")
        else:
            print(f"Pasta já existe: {folder}")

# Cria a hierarquia de pastas
ensure_folders_exist()


# Busca o primeiro arquivo PDF na pasta maps
pdf_files = [f for f in os.listdir(source_folder) if f.endswith('.pdf')]

if not pdf_files:
    print("Nenhum arquivo PDF encontrado na pasta maps.")
else:
    encrypted_pdf_path = os.path.join(source_folder, pdf_files[0])
    decrypted_pdf_path = os.path.join(decrypted_folder, f"decrypted_{pdf_files[0]}")

    try:
        # Tenta descriptografar o PDF
        with pikepdf.open(encrypted_pdf_path) as pdf:
            pdf.save(decrypted_pdf_path)
        print(f"PDF desbloqueado com sucesso! Salvo em: {decrypted_pdf_path}")

        # Move o PDF criptografado para a pasta processed
        shutil.move(encrypted_pdf_path, os.path.join(processed_folder, pdf_files[0]))
        print(f"PDF original criptografado movido para: {processed_folder}")

    except pikepdf.PasswordError:
        print(f"O PDF '{pdf_files[0]}' está protegido por senha e não pode ser desbloqueado sem ela.")
    except FileNotFoundError as e:
        print(f"Erro: Arquivo não encontrado. Verifique o caminho. {e}")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")


# Paths das pastas
input_folder = "./maps/decrypted"
processed_folder = "maps/decrypted/processed"

# Verificar se a pasta de processados existe, caso contrário, criá-la
os.makedirs(processed_folder, exist_ok=True)

# Obter a lista de PDFs na pasta de entrada
pdf_files = [file for file in os.listdir(input_folder) if file.lower().endswith(".pdf")]



if pdf_files:
    for file_name in pdf_files:
        input_pdf_path = os.path.join(input_folder, file_name)
        processed_pdf_path = os.path.join(processed_folder, file_name)
        
        try:
            full_text = ""
            reader = PdfReader(input_pdf_path)
            
            # 1️⃣ - Extrair texto e marcar páginas
            for idx, page in enumerate(reader.pages):
                full_text += f"------------------ PAGINA {idx} ----------------\n"
                full_text += page.extract_text()

            # 2️⃣ - Separar Páginas
            paginas = re.split(r"------------------ PAGINA \d+ ----------------", full_text)
            paginas = [pagina.strip() for pagina in paginas if pagina.strip()]
            print(f"\nTotal de páginas detectadas em '{file_name}': {len(paginas)}\n")

            # 3️⃣ - Separar por 'Tipo de responsabilidade' em cada página
            texto_paginas = {}
            for page_idx, pagina in enumerate(paginas, start=1):
                sub_paginas = re.split(r"\nTipo de responsabilidade\n", pagina)
                sub_paginas = [sub.strip() for sub in sub_paginas if sub.strip()]

                # Adiciona prefixo nos sub-blocos
                sub_paginas_dict = {}
                for sub_idx, sub_pagina in enumerate(sub_paginas, start=1):
                    sub_paginas_dict[f"sub_pagina{page_idx}.{sub_idx}"] = sub_pagina

                texto_paginas[f"pagina_{page_idx}"] = sub_paginas_dict
        

        except Exception as e:
            print(f"Ocorreu um erro ao processar '{file_name}': {e}")
        finally:
            # Mover PDF para a pasta de processados
            shutil.move(input_pdf_path, processed_pdf_path)
            print(f"PDF '{file_name}' movido para a pasta de processados: {processed_pdf_path}")
else:
    print("Nenhum PDF encontrado na pasta de entrada.")
# Out:
# Pasta já existe: ./maps/encrypted/
# Pasta já existe: ./maps/encrypted/processed
# Pasta já existe: ./maps/decrypted/
# Pasta já existe: ./maps/decrypted/processed
# PDF desbloqueado com sucesso! Salvo em: ./maps/decrypted/decrypted_7f9f93b9-3105-4dd0-8325-48b12bd59333.pdf
# PDF original criptografado movido para: ./maps/encrypted/processed
#
# Total de páginas detectadas em 'decrypted_510dbb12-bfc9-48b0-9787-06212253f60c.pdf': 7
#
# PDF 'decrypted_510dbb12-bfc9-48b0-9787-06212253f60c.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_510dbb12-bfc9-48b0-9787-06212253f60c.pdf
#
# Total de páginas detectadas em 'decrypted_ae6f8d6b-d923-4b09-87fe-06e465591d03.pdf': 4
#
# PDF 'decrypted_ae6f8d6b-d923-4b09-87fe-06e465591d03.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_ae6f8d6b-d923-4b09-87fe-06e465591d03.pdf
#
# Total de páginas detectadas em 'decrypted_1f03afe3-6bbc-4af5-aac2-6fb6542fd4ef.pdf': 0
#
# PDF 'decrypted_1f03afe3-6bbc-4af5-aac2-6fb6542fd4ef.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_1f03afe3-6bbc-4af5-aac2-6fb6542fd4ef.pdf
#
# Total de páginas detectadas em 'decrypted_f47a253e-d957-4e8d-a54b-69ac141e28d3.pdf': 9
#
# PDF 'decrypted_f47a253e-d957-4e8d-a54b-69ac141e28d3.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_f47a253e-d957-4e8d-a54b-69ac141e28d3.pdf
#
# Total de páginas detectadas em 'decrypted_2b073940-ce02-4d4a-8e26-b76055d06a70.pdf': 7
#
# PDF 'decrypted_2b073940-ce02-4d4a-8e26-b76055d06a70.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_2b073940-ce02-4d4a-8e26-b76055d06a70.pdf
#
# Total de páginas detectadas em 'decrypted_d4a7121b-fa48-4c79-839e-e44e80a0a45e.pdf': 11
#
# PDF 'decrypted_d4a7121b-fa48-4c79-839e-e44e80a0a45e.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_d4a7121b-fa48-4c79-839e-e44e80a0a45e.pdf
#
# Total de páginas detectadas em 'decrypted_ebee1f12-f48e-4319-82be-9227cee62566.pdf': 4
#
# PDF 'decrypted_ebee1f12-f48e-4319-82be-9227cee62566.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_ebee1f12-f48e-4319-82be-9227cee62566.pdf
#
# Total de páginas detectadas em 'decrypted_1b0349d8-d6b4-4651-a062-dff03f0d9d29.pdf': 6
#
# PDF 'decrypted_1b0349d8-d6b4-4651-a062-dff03f0d9d29.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_1b0349d8-d6b4-4651-a062-dff03f0d9d29.pdf
#
# Total de páginas detectadas em 'decrypted_e9b0462d-9027-4ceb-9ddd-cf718063f641.pdf': 0
#
# PDF 'decrypted_e9b0462d-9027-4ceb-9ddd-cf718063f641.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_e9b0462d-9027-4ceb-9ddd-cf718063f641.pdf
#
# Total de páginas detectadas em 'decrypted_a4280e5c-fcd0-420c-abe7-8fe1c6214d18.pdf': 7
#
# PDF 'decrypted_a4280e5c-fcd0-420c-abe7-8fe1c6214d18.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_a4280e5c-fcd0-420c-abe7-8fe1c6214d18.pdf
#
# Total de páginas detectadas em 'decrypted_a108bf14-54b9-4f78-b33f-69191f1141ff.pdf': 5
#
# PDF 'decrypted_a108bf14-54b9-4f78-b33f-69191f1141ff.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_a108bf14-54b9-4f78-b33f-69191f1141ff.pdf
#
# Total de páginas detectadas em 'decrypted_17db1cf9-a2de-4f6e-8e32-b0a71537d5ea.pdf': 5
#
# PDF 'decrypted_17db1cf9-a2de-4f6e-8e32-b0a71537d5ea.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_17db1cf9-a2de-4f6e-8e32-b0a71537d5ea.pdf
#
# Total de páginas detectadas em 'decrypted_6868b9eb-fc9b-4893-b785-e24c090fb363.pdf': 7
#
# PDF 'decrypted_6868b9eb-fc9b-4893-b785-e24c090fb363.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_6868b9eb-fc9b-4893-b785-e24c090fb363.pdf
#
# Total de páginas detectadas em 'decrypted_63e3821c-8e44-4b57-a264-eba05fc2039b.pdf': 8
#
# PDF 'decrypted_63e3821c-8e44-4b57-a264-eba05fc2039b.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_63e3821c-8e44-4b57-a264-eba05fc2039b.pdf
#
# Total de páginas detectadas em 'decrypted_2eaf8bfb-f221-43b4-b0dd-6b0d983aacf0.pdf': 10
#
# PDF 'decrypted_2eaf8bfb-f221-43b4-b0dd-6b0d983aacf0.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_2eaf8bfb-f221-43b4-b0dd-6b0d983aacf0.pdf
#
# Total de páginas detectadas em 'decrypted_89fbd46e-8fee-4349-9a7a-fad9616d6ae7.pdf': 7
#
# PDF 'decrypted_89fbd46e-8fee-4349-9a7a-fad9616d6ae7.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_89fbd46e-8fee-4349-9a7a-fad9616d6ae7.pdf
#
# Total de páginas detectadas em 'decrypted_35643b1a-9709-4371-a5e9-f631ba8b6603.pdf': 7
#
# PDF 'decrypted_35643b1a-9709-4371-a5e9-f631ba8b6603.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_35643b1a-9709-4371-a5e9-f631ba8b6603.pdf
#
# Total de páginas detectadas em 'decrypted_60b18865-dcbf-4ffc-a00a-8dca1cc89937.pdf': 8
#
# PDF 'decrypted_60b18865-dcbf-4ffc-a00a-8dca1cc89937.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_60b18865-dcbf-4ffc-a00a-8dca1cc89937.pdf
#
# Total de páginas detectadas em 'decrypted_bfecdc3c-cde4-4684-bf28-8442a04ed73d.pdf': 3
#
# PDF 'decrypted_bfecdc3c-cde4-4684-bf28-8442a04ed73d.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_bfecdc3c-cde4-4684-bf28-8442a04ed73d.pdf
#
# Total de páginas detectadas em 'decrypted_a214a426-632f-4f1b-b49c-4d63fd1aa67f.pdf': 10
#
# PDF 'decrypted_a214a426-632f-4f1b-b49c-4d63fd1aa67f.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_a214a426-632f-4f1b-b49c-4d63fd1aa67f.pdf
#
# Total de páginas detectadas em 'decrypted_95bf4256-300c-4f89-9c4a-8f82a3a5b9af.pdf': 0
#
# PDF 'decrypted_95bf4256-300c-4f89-9c4a-8f82a3a5b9af.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_95bf4256-300c-4f89-9c4a-8f82a3a5b9af.pdf
#
# Total de páginas detectadas em 'decrypted_3648a6eb-03f8-4c2a-b5f6-35f11d45ccae.pdf': 8
#
# PDF 'decrypted_3648a6eb-03f8-4c2a-b5f6-35f11d45ccae.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_3648a6eb-03f8-4c2a-b5f6-35f11d45ccae.pdf
#
# Total de páginas detectadas em 'decrypted_cc75dca3-a5ee-4f9c-b330-b3127d250c64.pdf': 9
#
# PDF 'decrypted_cc75dca3-a5ee-4f9c-b330-b3127d250c64.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_cc75dca3-a5ee-4f9c-b330-b3127d250c64.pdf
#
# Total de páginas detectadas em 'decrypted_5dd584e3-126c-4a99-8aaa-8d43fe3ac546.pdf': 10
#
# PDF 'decrypted_5dd584e3-126c-4a99-8aaa-8d43fe3ac546.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_5dd584e3-126c-4a99-8aaa-8d43fe3ac546.pdf
#
# Total de páginas detectadas em 'decrypted_9286bfa6-9e1d-4e45-a675-50faf600e50e.pdf': 6
#
# PDF 'decrypted_9286bfa6-9e1d-4e45-a675-50faf600e50e.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_9286bfa6-9e1d-4e45-a675-50faf600e50e.pdf
#
# Total de páginas detectadas em 'decrypted_29b46060-4f0e-40c8-8f5b-3cfe7d0ad44c.pdf': 5
#
# PDF 'decrypted_29b46060-4f0e-40c8-8f5b-3cfe7d0ad44c.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_29b46060-4f0e-40c8-8f5b-3cfe7d0ad44c.pdf
#
# Total de páginas detectadas em 'decrypted_af2b217a-9944-42ba-b8fd-e5a07619eebf.pdf': 6
#
# PDF 'decrypted_af2b217a-9944-42ba-b8fd-e5a07619eebf.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_af2b217a-9944-42ba-b8fd-e5a07619eebf.pdf
# PDF 'decrypted_c8a7a8b1-8de9-4a64-ade6-621402d41834.pdf' movido para a pasta de processados: maps/decrypted/processed/decrypted_c8a7a8b1-8de9-4a64-ade6-621402d41834.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 80
#      78 for idx, page in enumerate(reader.pages):
#      79     full_text += f"------------------ PAGINA {idx} ----------------\n"
# ---> 80     full_text += page.extract_text()
#      82 # 2️⃣ - Separar Páginas
#      83 paginas = re.split(r"------------------ PAGINA \d+ ----------------", full_text)
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/generic/_data_structures.py:877, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     875     stream_bytes = BytesIO(stream_data_bytes)
#     876 self.forced_encoding = forced_encoding
# --> 877 self.__parse_content_stream(stream_bytes)
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/generic/_data_structures.py:943, in ContentStream.__parse_content_stream(self, stream)
#     941         peek = stream.read(1)
#     942 else:
# --> 943     operands.append(read_object(stream, None, self.forced_encoding))
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/generic/_data_structures.py:1077, in read_object(stream, pdf, forced_encoding)
#    1075         return IndirectObject.read_from_stream(stream, pdf)
#    1076     else:
# -> 1077         return NumberObject.read_from_stream(stream)
#    1078 else:
#    1079     stream.seek(-20, 1)
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/generic/_base.py:407, in NumberObject.read_from_stream(stream)
#     405 num = read_until_regex(stream, NumberObject.NumberPattern)
#     406 if num.find(b".") != -1:
# --> 407     return FloatObject(num)
#     408 return NumberObject(num)
#
# File ~/Documents/mapa_regex_gb_v1/.venv/lib/python3.13/site-packages/PyPDF2/generic/_base.py:330, in FloatObject.__new__(cls, value, context)
#     326 def __new__(
#     327     cls, value: Union[str, Any] = "0", context: Optional[Any] = None
#     328 ) -> "FloatObject":
#     329     try:
# --> 330         return decimal.Decimal.__new__(cls, str_(value), context)
#     331     except Exception:
#     332         # If this isn't a valid decimal (happens in malformed PDFs)
#     333         # fallback to 0
#     334         logger_warning(f"FloatObject ({value}) invalid; use 0.0 instead", __name__)
#
# KeyboardInterrupt:

# %%
import re
import pandas as pd


# Regexes para capturar os elementos gerais e específicos
regexes = {
    # Informações gerais (por página)
    'nome': re.compile(r'Nome:\s+(.+)', re.MULTILINE),
    'nif': re.compile(r'Nº de Identificação:\s+(\d+)'),
    'mes_mapa': re.compile(r'Responsabilidades de crédito referentes a\s+(.+)'),
    
    # Informações específicas (por sub-página)
    'instituicao': re.compile(r'Informação comunicada pela instituição:\s+(.+)', re.MULTILINE),
    'total_em_divida': re.compile(r"Montantes\s+Total em dívida\s+do qual, em incumprimento\s+([\d\s,]+) €"),
    'litigio': re.compile(r'Em litígio judicial\s+(Sim|Não)'),
    'abatido_ativo': re.compile(r'Abatido ao ativo\s+([\d\s,.]+) €'),
    'garantias': re.compile(r"Tipo\s+Valor\s+Número\s+\d+\s+([\d\s,.]+) €"),
    'num_devedores': re.compile(r"Nº devedores no contrato\s+(\d+)"),
    'prod_financeiro': re.compile(r"Produto financeiro\s+(.+?)\s+(?:Tipo de responsabilidade|Fim)", re.DOTALL),
    'dat_inicio': re.compile(r"Início\s+(\d{4}-\d{2}-\d{2})"),
    'dat_fim': re.compile(r"Fim\s+(\d{4}-\d{2}-\d{2})\s+Em litígio judicial"),
    'entrada_incumpr': re.compile(r"Entrada incumpr\.\s+(Não Aplicável|\d{4}-\d{2}-\d{2})")
}

# Função para aplicar regex em texto
def get_feature(text, regex_string):
    match = regexes[regex_string].search(text)
    return match.group(1).strip() if match else None

# Inicializar lista para armazenar os dados
data = []

# Iterar sobre as páginas e sub-páginas
for page_number, sub_paginas in texto_paginas.items():
    # Primeiro, capturar as informações gerais (comuns para todas as sub-páginas)
    page_text = "\n".join(sub_paginas.values())  # Junta todo o conteúdo da página para capturar as infos gerais
    nome = get_feature(page_text, 'nome')
    nif = get_feature(page_text, 'nif')
    mes_mapa = get_feature(page_text, 'mes_mapa')

    for sub_page_number, sub_text in sub_paginas.items():
        # Capturar as informações específicas por sub-página
        row = {
            'pagina_pdf': page_number,
            'sub_pagina': sub_page_number,
            'nome': nome,
            'nif': nif,
            'mes_mapa': mes_mapa,
            'instituicao': get_feature(sub_text, 'instituicao'),
            'divida': get_feature(sub_text, 'total_em_divida'),
            'litigio': get_feature(sub_text, 'litigio'),
            'parcela': get_feature(sub_text, 'abatido_ativo'),
            'garantias': get_feature(sub_text, 'garantias'),
            'num_devedores': get_feature(sub_text, 'num_devedores'),
            'prod_financeiro': get_feature(sub_text, 'prod_financeiro'),
            'entrada_incumpr': get_feature(sub_text, 'entrada_incumpr'),
            'dat_inicio': get_feature(sub_text, 'dat_inicio'),
            'dat_fim': get_feature(sub_text, 'dat_fim')
        }
        data.append(row)

# Criar o DataFrame
df = pd.DataFrame(data)

texto_paginas
# Out:
# {'pagina_1': {'sub_pagina1.1': 'Informação comunicada pela instituição: BANCO SANTANDER TOTTA, S.A. (0018)\nMontantes\nTotal em dívida\ndo qual, em incumprimento\n65\xa0343,32 €\n0,00 €\nNº devedores no contrato\n1\nInício\n2008-03-28\nTipo de negociação\nTotalmente nova\nProduto financeiro\nCrédito à habitação',
#   'sub_pagina1.2': 'Devedor\nFim\n2058-04-07\nEm litígio judicial\nNão\nVencido\n0,00 €\nEntrada incumpr.\nNão Aplicável\nTipo \nValor\nNúmero\n0100\n130\xa0686,64 €\n2\n1410\n90\xa0000,00 €\n1\n-\n-\n-\nGarantias\nAbatido ao ativo\n292,75 €\n0,00 €\nPotencial\n0,00 €\nPrestação \nPeriodicidade\nMensal\nResponsabilidades de crédito relativas a 30 de novembro de 2024\nData de Emissão: \n26-12-2024 17:54:36 \nInformação detalhada - pág. 1 de 3\nCentral de Responsabilidades de Crédito\nNome: \nGRAÇA RAQUEL FREITAS CAMARA\nTipo de Identificação: \nNIF/NIPC\nNº de Identificação: \n222609770\nLegal Entity Identifier (LEI): \n \nPaís da Entidade: \nPortugal\nResponsabilidades de crédito referentes a \nnovembro de 2024'},
#  'pagina_2': {'sub_pagina2.1': 'Informação comunicada pela instituição: UNIVERSO, IME, S.A. (7500)\nMontantes\nTotal em dívida\ndo qual, em incumprimento\n844,65 €\n144,08 €\nNº devedores no contrato\n1\nInício\n2021-05-01\nTipo de negociação\nTotalmente nova\nProduto financeiro\nCartão de crédito - com período de free-float',
#   'sub_pagina2.2': 'Devedor\nFim\n9999-12-31\nEm litígio judicial\nNão\nVencido\n144,08 €\nEntrada incumpr.\n2024-07-08\nTipo \nValor\nNúmero\n-\n-\n-\nGarantias\nAbatido ao ativo\n172,71 €\n0,00 €\nPotencial\n0,00 €\nPrestação \nPeriodicidade\nMensal\nResponsabilidades de crédito relativas a 30 de novembro de 2024\nData de Emissão: \n26-12-2024 17:54:36 \nInformação detalhada - pág. 2 de 3\nCentral de Responsabilidades de Crédito\nNome: \nGRAÇA RAQUEL FREITAS CAMARA\nTipo de Identificação: \nNIF/NIPC\nNº de Identificação: \n222609770\nLegal Entity Identifier (LEI): \n \nPaís da Entidade: \nPortugal\nResponsabilidades de crédito referentes a \nnovembro de 2024'},
#  'pagina_3': {'sub_pagina3.1': 'Informação comunicada pela instituição: COFIDIS (0921)\nMontantes\nTotal em dívida\ndo qual, em incumprimento\n5\xa0187,59 €\n273,41 €\nNº devedores no contrato\n2\nInício\n2023-09-06\nTipo de negociação\nTotalmente nova\nProduto financeiro\nCrédito pessoal',
#   'sub_pagina3.2': 'Devedor\nFim\n2026-11-25\nEm litígio judicial\nNão\nVencido\n273,41 €\nEntrada incumpr.\n2024-11-26\nTipo \nValor\nNúmero\n-\n-\n-\nGarantias\nAbatido ao ativo\n260,93 €\n0,00 €\nPotencial\n0,00 €\nPrestação \nPeriodicidade\nMensal\nResponsabilidades de crédito relativas a 30 de novembro de 2024\n0100\nFiança/Aval\n1410\nImóveis destinados à habitação \n– \nConcluídos\nLegenda\nOutras informações:\n9999-12-31: data não definida\nTipos de Garantia:\nFim de relatório\nA informação  prestada,  extraída  da  Central  de  Responsabilidades  de  Crédito (CRC)  no  momento  em  que  a  consulta  foi efetuada,  é  da \nresponsabilidade das entidades que a tenham transmitido, cabendo exclusivamente a estas proceder à sua alteração ou retificação (Artigo 2º, n.º 4, do Decreto-\nLei n.º 204/2008, de 14 de outubro).\nOs dados contidos na CRC encontram-se cobertos pelo sigilo bancário. O Banco de Portugal apenas está habilitado a facultar o acesso e a utilização destes \ndados ao respetivo titular, bem como nas situações e para as finalidades expressamente previstas na lei.\nData de Emissão: \n26-12-2024 17:54:36 \nInformação detalhada - pág. 3 de 3\nCentral de Responsabilidades de Crédito\nNome: \nGRAÇA RAQUEL FREITAS CAMARA\nTipo de Identificação: \nNIF/NIPC\nNº de Identificação: \n222609770\nLegal Entity Identifier (LEI): \n \nPaís da Entidade: \nPortugal\nResponsabilidades de crédito referentes a \nnovembro de 2024'},
#  'pagina_4': {'sub_pagina4.1': 'Tipo de Responsabilidade: \nDevedor\nResumo das Responsabilidades de Crédito relativas a 30 de novembro de 2024\nConjunto\nMontante em dívida\nTotal\nEm incumprimento\nMontante Potencial\nN.º Produtos\nProdutos c/ garantia\nCrédito pessoal \n5\xa0187,59 €\n273,41 €\n0,00 €\n1\n0\n5\xa0187,59 €\n273,41 €\n0,00 €\n1\n0\nIndividual\nMontante em dívida\nTotal\nEm incumprimento\nMontante Potencial\nN.º Produtos\nProdutos c/ garantia\nCartão de crédito - com \nperíodo de free-float\n844,65 €\n144,08 €\n0,00 €\n1\n0\nCrédito à habitação\n65\xa0343,32 €\n0,00 €\n0,00 €\n1\n1\n66\xa0187,97 €\n144,08 €\n0,00 €\n2\n1\nInstituições e produtos financeiros\nNº de instituições que comunicaram informação:\n3\nNº de instituições que comunicaram incumprimento:\n2\nNº total de produtos financeiros comunicados:\n3\nFim de relatório\nA informação  prestada,  extraída  da  Central  de  Responsabilidades  de  Crédito (CRC)  no  momento  em  que  a  consulta  foi efetuada,  é  da \nresponsabilidade das entidades que a tenham transmitido, cabendo exclusivamente a estas proceder à sua alteração ou retificação (Artigo 2º, n.º 4, do Decreto-\nLei n.º 204/2008, de 14 de outubro).\nOs dados contidos na CRC encontram-se cobertos pelo sigilo bancário. O Banco de Portugal apenas está habilitado a facultar o acesso e a utilização destes \ndados ao respetivo titular, bem como nas situações e para as finalidades expressamente previstas na lei.\nData de Emissão: \n26-12-2024 17:54:36 \nQuadro Síntese - pág. 1 de 1\nCentral de Responsabilidades de Crédito\nNome: \nGRAÇA RAQUEL FREITAS CAMARA\nTipo de Identificação: \nNIF/NIPC\nPaís da Entidade: \nPortugal\nNº de Identificação: \n222609770\nLegal Entity Identifier (LEI): \nResponsabilidades de crédito referentes a \nnovembro de 2024'}}
